# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Car_Purchasing_Data.csv", encoding='ISO-8859-1')

# %%
df.head()
# Out:
#      Customer Name                                    Customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         Country  Gender        Age  Annual Salary  Credit Card Debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      Net Worth  Car Purchase Amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.describe()
# Out:
#            Gender         Age  Annual Salary  Credit Card Debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.241674   62127.239608       9607.645049
# std      0.500465    7.978862   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   40.949969   54391.977195       7397.515792
# 50%      1.000000   46.049901   62915.497035       9655.035568
# 75%      1.000000   51.612263   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             Net Worth  Car Purchase Amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
# Customer Name          500 non-null object
# Customer e-mail        500 non-null object
# Country                500 non-null object
# Gender                 500 non-null int64
# Age                    500 non-null float64
# Annual Salary          500 non-null float64
# Credit Card Debt       500 non-null float64
# Net Worth              500 non-null float64
# Car Purchase Amount    500 non-null float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 35.3+ KB

# %%
# Visualization
sns.pairplot(df) # no gender column, as it is a categorical feature

# %%
X = df.drop(["Customer Name", "Customer e-mail", "Country", "Car Purchase Amount"], axis=1)

# %%
X
# Out:
#      Gender        Age  Annual Salary  Credit Card Debt    Net Worth
# 0         0  41.851720    62812.09301      11609.380910  238961.2505
# 1         0  40.870623    66646.89292       9572.957136  530973.9078
# 2         1  43.152897    53798.55112      11160.355060  638467.1773
# 3         1  58.271369    79370.03798      14426.164850  548599.0524
# 4         1  57.313749    59729.15130       5358.712177  560304.0671
# ..      ...        ...            ...               ...          ...
# 495       0  41.462515    71942.40291       6995.902524  541670.1016
# 496       1  37.642000    56039.49793      12301.456790  360419.0988
# 497       1  53.943497    68888.77805      10611.606860  764531.3203
# 498       1  59.160509    49811.99062      14013.034510  337826.6382
# 499       1  46.731152    61370.67766       9391.341628  462946.4924
#
# [500 rows x 5 columns]

# %%
y = df["Car Purchase Amount"]

# %%
y[0:10]
# Out:
# 0    35321.45877
# 1    45115.52566
# 2    42925.70921
# 3    67422.36313
# 4    55915.46248
# 5    56611.99784
# 6    28925.70549
# 7    47434.98265
# 8    48013.61410
# 9    38189.50601
# Name: Car Purchase Amount, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled[0:10]
# Out:
# array([[0.        , 0.4370344 , 0.53515116, 0.57836085, 0.22342985],
#        [0.        , 0.41741247, 0.58308616, 0.476028  , 0.52140195],
#        [1.        , 0.46305795, 0.42248189, 0.55579674, 0.63108896],
#        [1.        , 0.76542739, 0.74212547, 0.71990778, 0.53938679],
#        [1.        , 0.74627499, 0.49661439, 0.26425689, 0.55133068],
#        [1.        , 0.73649786, 0.60624815, 0.70751118, 0.4168218 ],
#        [1.        , 0.5321463 , 0.24768153, 0.29439498, 0.3126257 ],
#        [1.        , 0.60386032, 0.39690293, 0.54701993, 0.62174735],
#        [0.        , 0.53169489, 0.47674074, 0.16788059, 0.62250921],
#        [1.        , 0.46647563, 0.41821377, 0.64241601, 0.46596261]])

# %%
scaler.data_max_
# Out:
# array([1.e+00, 7.e+01, 1.e+05, 2.e+04, 1.e+06])

# %%
y = y.values.reshape(-1, 1)

# %%
y_scaled = scaler.fit_transform(y)

# %%
y[0:10]
# Out:
# array([[35321.45877],
#        [45115.52566],
#        [42925.70921],
#        [67422.36313],
#        [55915.46248],
#        [56611.99784],
#        [28925.70549],
#        [47434.98265],
#        [48013.6141 ],
#        [38189.50601]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.25, random_state=50)

# %%
X_train.shape
# Out:
# (375, 5)

# %%
X_test.shape
# Out:
# (125, 5)

# %%
import tensorflow.keras
from keras.models import Sequential
from keras.layers import Dense, Dropout

model = Sequential()
model.add(Dense(25, input_dim=5, activation='relu'))
model.add(Dense(25, activation='relu'))
model.add(Dense(1, activation='linear'))
# Out:
# Using TensorFlow backend.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 25)                150
# _________________________________________________________________
# dense_2 (Dense)              (None, 25)                650
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 26
# =================================================================
# Total params: 826
# Trainable params: 826
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss="mean_squared_error")

# %%
ep_history=model.fit(X_train, y_train, epochs=50, batch_size=25, verbose=1, validation_split=0.2)
# Out:
# Train on 300 samples, validate on 75 samples
# Epoch 1/50
# 300/300 [==============================] - 0s 269us/step - loss: 0.3469 - val_loss: 0.2314
# Epoch 2/50
# 300/300 [==============================] - 0s 40us/step - loss: 0.1491 - val_loss: 0.0899
# Epoch 3/50
# 300/300 [==============================] - 0s 60us/step - loss: 0.0569 - val_loss: 0.0340
# Epoch 4/50
# 300/300 [==============================] - 0s 60us/step - loss: 0.0303 - val_loss: 0.0208
# Epoch 5/50
# 300/300 [==============================] - 0s 60us/step - loss: 0.0207 - val_loss: 0.0135
# Epoch 6/50
# 300/300 [==============================] - 0s 60us/step - loss: 0.0155 - val_loss: 0.0110
# Epoch 7/50
# 300/300 [==============================] - 0s 50us/step - loss: 0.0139 - val_loss: 0.0101
# Epoch 8/50
# 300/300 [==============================] - 0s 57us/step - loss: 0.0127 - val_loss: 0.0096
# Epoch 9/50
# 300/300 [==============================] - 0s 60us/step - loss: 0.0115 - val_loss: 0.0089
# Epoch 10/50
# 300/300 [==============================] - 0s 60us/step - loss: 0.0104 - val_loss: 0.0081
# Epoch 11/50
# 300/300 [==============================] - 0s 57us/step - loss: 0.0094 - val_loss: 0.0077
# Epoch 12/50
# 300/300 [==============================] - 0s 63us/step - loss: 0.0086 - val_loss: 0.0072
# Epoch 13/50
# 300/300 [==============================] - 0s 53us/step - loss: 0.0078 - val_loss: 0.0067
# Epoch 14/50
# 300/300 [==============================] - 0s 60us/step - loss: 0.0071 - val_loss: 0.0063
# Epoch 15/50
# 300/300 [==============================] - 0s 60us/step - loss: 0.0063 - val_loss: 0.0059
# Epoch 16/50
# 300/300 [==============================] - 0s 50us/step - loss: 0.0056 - val_loss: 0.0055
# Epoch 17/50
# 300/300 [==============================] - 0s 50us/step - loss: 0.0047 - val_loss: 0.0050
# Epoch 18/50
# 300/300 [==============================] - 0s 60us/step - loss: 0.0038 - val_loss: 0.0046
# Epoch 19/50
# 300/300 [==============================] - 0s 60us/step - loss: 0.0033 - val_loss: 0.0043
# Epoch 20/50
# 300/300 [==============================] - 0s 53us/step - loss: 0.0030 - val_loss: 0.0041
# Epoch 21/50
# 300/300 [==============================] - 0s 57us/step - loss: 0.0027 - val_loss: 0.0040
# Epoch 22/50
# 300/300 [==============================] - 0s 57us/step - loss: 0.0026 - val_loss: 0.0040
# Epoch 23/50
# 300/300 [==============================] - 0s 53us/step - loss: 0.0024 - val_loss: 0.0038
# Epoch 24/50
# 300/300 [==============================] - 0s 43us/step - loss: 0.0023 - val_loss: 0.0037
# Epoch 25/50
# 300/300 [==============================] - 0s 60us/step - loss: 0.0021 - val_loss: 0.0036
# Epoch 26/50
# 300/300 [==============================] - 0s 57us/step - loss: 0.0020 - val_loss: 0.0034
# Epoch 27/50
# 300/300 [==============================] - 0s 40us/step - loss: 0.0018 - val_loss: 0.0031
# Epoch 28/50
# 300/300 [==============================] - 0s 63us/step - loss: 0.0017 - val_loss: 0.0030
# Epoch 29/50
# 300/300 [==============================] - 0s 66us/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 30/50
# 300/300 [==============================] - 0s 50us/step - loss: 0.0015 - val_loss: 0.0027
# Epoch 31/50
# 300/300 [==============================] - 0s 57us/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 32/50
# 300/300 [==============================] - 0s 57us/step - loss: 0.0014 - val_loss: 0.0024
# Epoch 33/50
# 300/300 [==============================] - 0s 63us/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 34/50
# 300/300 [==============================] - 0s 47us/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 35/50
# 300/300 [==============================] - 0s 60us/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 36/50
# 300/300 [==============================] - 0s 53us/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 37/50
# 300/300 [==============================] - 0s 57us/step - loss: 9.7808e-04 - val_loss: 0.0017
# Epoch 38/50
# 300/300 [==============================] - 0s 53us/step - loss: 9.2157e-04 - val_loss: 0.0016
# Epoch 39/50
# 300/300 [==============================] - 0s 76us/step - loss: 8.6388e-04 - val_loss: 0.0015
# Epoch 40/50
# 300/300 [==============================] - 0s 43us/step - loss: 8.4463e-04 - val_loss: 0.0014
# Epoch 41/50
# 300/300 [==============================] - 0s 60us/step - loss: 7.9448e-04 - val_loss: 0.0013
# Epoch 42/50
# 300/300 [==============================] - 0s 60us/step - loss: 7.1169e-04 - val_loss: 0.0012
# Epoch 43/50
# 300/300 [==============================] - 0s 47us/step - loss: 6.5835e-04 - val_loss: 0.0011
# Epoch 44/50
# 300/300 [==============================] - 0s 53us/step - loss: 6.0097e-04 - val_loss: 0.0010
# Epoch 45/50
# 300/300 [==============================] - 0s 70us/step - loss: 5.6159e-04 - val_loss: 9.4292e-04
# Epoch 46/50
# 300/300 [==============================] - 0s 47us/step - loss: 5.3841e-04 - val_loss: 8.9143e-04
# Epoch 47/50
# 300/300 [==============================] - 0s 53us/step - loss: 4.9295e-04 - val_loss: 8.0613e-04
# Epoch 48/50
# 300/300 [==============================] - 0s 60us/step - loss: 4.6791e-04 - val_loss: 7.7949e-04
# Epoch 49/50
# 300/300 [==============================] - 0s 43us/step - loss: 4.5103e-04 - val_loss: 7.7887e-04
# Epoch 50/50
# 300/300 [==============================] - 0s 57us/step - loss: 4.2359e-04 - val_loss: 6.4140e-04

# %%
ep_history.history.keys()
# Out:
# dict_keys(['val_loss', 'loss'])

# %%
plt.plot(ep_history.history["loss"])
plt.plot(ep_history.history["val_loss"])
plt.title("Model Progress")
plt.ylabel("Training-Validation Loss")
plt.xlabel("Epochs")
plt.legend(["Training Loss", "Validation Loss"])
plt.show()

# %%
# so we can see after almost 10 epochs there was not significant improvement in model. So we can change our epochs to 10. 
# Make sure you try it with yourself and also try to play with the number of neurons.

# %%
# Compare with test data. You can see model is providing very good accuracy.

# %%
plt.figure(figsize=(10, 6))
plt.plot(y_test)
plt.plot(model.predict([X_test]))
plt.legend(["Predicted Values", "Original Values"])

# %%
y_test[0:10]
# Out:
# array([[0.51220225],
#        [0.76168793],
#        [0.6538108 ],
#        [0.53430602],
#        [0.52673735],
#        [0.21316327],
#        [0.56811431],
#        [0.42720002],
#        [0.56035434],
#        [0.65554063]])

# %%
test_loss = model.evaluate(X_test, y_test)
# Out:
# 125/125 [==============================] - 0s 24us/step

# %%
test_loss # loss value, which is very small. It means our model is good.
# Out:
# 0.0006279701050370931

# %%
# Predict
X_predict = np.array([[1, 40, 40000, 10000, 80000]])
y_predict = model.predict(X_predict)
y_predict[0][0]  # So congrats our model is evaluating
# Out:
# 47860.836

# %%
# Model Tuning

# %%
def create_model(optimizer='adam'):
    # create model
    model = Sequential()
    model.add(Dense(units=25, input_dim=5, activation='relu'))
    model.add(Dense(units=25, activation='relu'))
    model.add(Dense(units=1, activation='linear'))
    model.compile(optimizer="adam", loss="mean_squared_error", metrics=["accuracy"])
    return model

# %%
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV

# %%
model_new = KerasClassifier(build_fn=create_model, epochs=100, batch_size=10, verbose=0)

# %%
optimizer = ['SGD', 'Adam',]
epochs=[10, 30, 50, 70]
units=[5, 10, 25]
param_grid = dict(optimizer=optimizer, epochs=epochs)

grid = GridSearchCV(estimator=model_new, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(X_train, y_train)

# %%
grid_result.best_params_
# Out:
# {'epochs': 10, 'optimizer': 'Adam'}

# %%
grid_result.best_score_
# Out:
# 0.00800000037997961
